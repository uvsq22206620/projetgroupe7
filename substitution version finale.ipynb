# %% [markdown]
# Chiffrement par substitution

# %%
import random
import string
dictionnaire = {}




def encryptage_substitution (message= ""):

    #DEMANDER A L'UTILISATEUR DE SUPPRIMER LES CARACTERES SPECIAUX ET/OU LES ESPACES
    supprimer_caracteres_speciaux = input ("Souhaitez-vous supprimer les caractères spéciaux ? (Répondre par 'oui' ou 'non')")
    while supprimer_caracteres_speciaux.lower() not in ["oui", "non"]: #on met tous les caractères du message en minuscule
        supprimer_caracteres_speciaux = input ("Souhaitez-vous supprimer les caractères spéciaux ? Une réponse par 'oui' ou 'non' est obligatoire")
    
    supprimer_espaces = input ("Souhaitez-vous supprimer les espaces ? (Répondre par 'oui' ou 'non')")
    while supprimer_espaces.lower() not in ["oui", "non"]:
        supprimer_espaces = input ("Souhaitez-vous supprimer les espaces ? Une réponse par 'oui' ou 'non' est obligatoire")

    #MIS EN PLACE DES VARIABLES
    liste = []
    mot_code = ""
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    caracteres_speciaux = string.punctuation #on place l'ensemble des caractères spéciaux dans une chaîne de caractère. 
    alphabet_melange = random.sample(alphabet, len(alphabet)) #fonction qui permet de melanger aléatoirement une chaîne de caractère, ici c'est l'alphabet. Alphabet mélangé va donc devenir notre clé de chiffrement

    #REMPLACEMENT DES ESPACES ET SUPPRESSION DES CARACTERES SPECIAUX
    if supprimer_espaces.lower() == "oui" :
        message = message.replace(" ", "") #on remplace tous les espaces par du "vide", si l'utilisateur décide de les supprimer

    if supprimer_caracteres_speciaux.lower() == "oui" : #on réutilise 'if' car ces deux propositions doivent être vérifiées
        for lettre in message.lower(): 
            if lettre not in caracteres_speciaux :
                liste.append(lettre) #si l'utilisateur décide de supprimer tous les caractères spéciaux, on ajoute à la liste uniquement ce qui n'est pas un caractère spécial

    elif supprimer_caracteres_speciaux.lower() == "non" and supprimer_espaces.lower() == "non":
        for lettre in message.lower():
            liste.append(lettre) #si l'utilisateur décide au contraire de conserver les caractères spéciaux et les espaces, le message est placé caractères par caractères dans une liste

    #SUBSTITUTION
    for lettre in liste: 
        if lettre in alphabet :
            mot_code += alphabet_melange[alphabet.index(lettre)]#si le caractère est une lettre de l'alphabet, on ajoute au mot codé, la lettre positionnée à la même position dans l'alphabet mélangé, que la lettre initial dans l'alphabet normal.
        else :
            mot_code += lettre #on ajoute à la chaîne de caractère notre caractère codé

    #FIN DE LA FONCTION, RETOUR DU MOT CODE
    return mot_code







#CODER UN MESSAGE
coder_un_message = input("Souhaitez-vous coder un message ? (Répondre par 'oui' ou 'non')")
while coder_un_message.lower() not in ["oui", "non"]: 
    coder_un_message = input("Souhaitez-vous coder un message ? Une réponse par 'oui' ou par 'non' est obligatoire)")
if coder_un_message == 'oui' :
    message_chiffre = encryptage_substitution(message = input("Saisir le message à coder"))
    print("le message codé est :", message_chiffre)


#CODER UN FICHIER TEXTE 
coder_un_fichier_texte = input("Souhaitez-vous coder un fichier texte ? Répondre par 'oui' ou par 'non'")

if coder_un_fichier_texte.lower() == "oui" :
    nom_du_fichier = input("Entrez le nom du fichier avec l'extension '.txt'")
    with open(nom_du_fichier, "r") as fichier :
        message_fichier = fichier.read()
        mot_code = encryptage_substitution(message_fichier)
        print ("Le message du fichier codé est :", mot_code)
# Out:
# le message codé est : smyjg r'lsg ghubms

# %% [markdown]
# Déchiffrement, force brute :

# %%
import random

def decryptage_substitution(message_code=""): 

    #MIS EN PLACE DE VARIABLES POUR LA FONCTION
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    cle_de_dechiffrement = random.sample(alphabet, len(alphabet))
    message_dechiffre = ""
    


    #DECHIFFREMENT PAR FORCE BRUTE
    for caractere in message_code:
        if caractere in alphabet:
            message_dechiffre += cle_de_dechiffrement[alphabet.index(caractere)] #on fait le chemin inverse de l'encryptage jusqu'à trouver la bonne combinaison, si le caractère dans le message n'est pas une lettre alors il n'a pas été codé et est ajouté tel quel au mot 
        else:
            message_dechiffre += caractere

    #FIN DE LA FONCTION, RETOUR DE LA VARIABLE
    return message_dechiffre



#MIS EN PLACE DE VARIABLES
message_code = input("Entrez le message chiffré à déchiffer")
nombre_de_tentatives = int(input("Entrez le nombre de tentatives que vous souhaitez voir (choisir NECESSAIREMENT un nombre positif (ou nul))")) #si le nombre de tentative = 0 alors le code ne rend pas de valeur


#NOMBRE DE TENTATIVES
for i in range(nombre_de_tentatives):
    essai = decryptage_substitution(message_code)
    if essai not in dictionnaire :
        dictionnaire[essai] = 1 #si la lettre n'est pas enregistrée dans le dictionnaire, maintenant elle y existe et on y associe sa 'fréquence' qui est de 1
        print (essai) #on renvoit ensuite ce que le programme a déchiffré à l'utilisateur
    else :
        continue #si la lettre est déjà dans le dictionnaire, le programme ne le renvoit pas (pour éviter de trouver des similitudes dans ce que peut envoyer python), et continue de le décrypter jusquà 'nombres_de_tentatives'
    
print(dictionnaire)
# Out:
# ydcqm e'bym maofdy
# tdwaz b'otz zhlvdt
# ngoxd k'snd dqfrgn
# zbnms l'gzs sijrbz
# vodgi s'kvi iywmov
# lkymn i'zln negbkl
# letdi z'mli ivkjel
# qitxh a'dqh hgbwiq
# xoumy p'fxy ydnkox
# igncf r'zif fkwogi
# lavwc n'slc cpxgal
# atsvq p'daq qxurta
# rhqwf c'drf fpbthr
# xdkjl h'vxl lnybdx
# afpmy g'vay ykcdfa
# pysat m'wpt tdxhyp
# qijct g'uqt twzeiq
# sltkg o'qsg gjxfls
# ikuqh p'jih hwgeki
# penkm c'fpm mvhrep
# qtifv k'sqv vruhtq
# zhjwm s'gzm mxuehz
# sixhj k'ysj jfuvis
# qigfj k'yqj jnzviq
# zmuyn i'bzn nearmz
# mkexj l'imj jrvokm
# bpund s'ibd dqacpb
# lhqpw a'flw wguchl
# yvcel d'oyl lmibvy
# iylhj b'tij jnmeyi
# gktse x'zge eqfhkg
# jqrkp g'xjp pnwbqj
# xjgyf u'qxf fewojx
# wgktj u'nwj jchygw
# lobqn k'cln nyjfol
# hwzsn x'chn nldewh
# ctglp j'mcp porntc
# ecsdn r'oen nfagce
# kwxns d'jks sohmwk
# xvsnu j'lxu urwkvx
# urmpv c'iuv vqdkru
# qvwfx s'cqx xkiovq
# eoptd j'ued dlvcoe
# vwxyj g'avj jdoswv
# karfn b'vkn nyqmak
# ufiwm h'kum mjlvfu
# muwcr o'qmr rzjvum
# mzoyk b'dmk katlzm
# pbvdk i'gpk kseobp
# audqz g'xaz zesjua
# fnkmx c'hfx xbygnf
# koajg q'bkg ghudok
# gnkde x'fge euizng
# prdzb j'gpb byqhrp
# libfz g'klz zudmil
# cirbu z'ocu utfkic
# blend c'rbd dkpmlb
# gbnui d'pgi icoebg
# mnlcd x'hmd dbponm
# sixru h'qsu utzgis
# gsice r'kge ebhysg
# kvlcm b'nkm mgsdvk
# wtaxy s'bwy yhmitw
# potuc v'kpc cdmgop
# zrimu k'lzu uvcsrz
# xyobm s'rxm mvhgyx
# zqsrj l'hzj jvxtqz
# fvzju c'xfu urdovf
# nurob v'mnb bpqgun
# uxbml h'gul lzptxu
# puqsl d'apl lfmiup
# pcjkt g'fpt turqcp
# paqzi w'mpi ihcsap
# aioqb w'pab bglvia
# qsyjv t'lqv vrpksq
# stpwh n'ush hmbjts
# zmyxw d'pzw wearmz
# cmayd g'ocd dnpwmc
# ucnwa s'hua aflgcu
# slban e'tsn nriqls
# ahebu x'sau udnjha
# jgxfz w'ijz zcaegj
# phqrd c'wpd dikghp
# vipzw x'lvw wnrciv
# chjnz e'lcz zxskhc
# wlmga f'qwa abdplw
# olvqe p'yoe egxwlo
# lrnqk w'clk kuatrl
# jsfgd x'ljd dumosj
# vtked w'avd dzjhtv
# ipsxg f'dig glaepi
# niptd k'mnd dvroin
# zafej b'uzj jydlaz
# egtqr p'ler rnyjge
# pzlky b'gpy yoejzp
# hbgki l'uhi itzabh
# srlpv d'gsv vzaors
# jnmok h'pjk kiurnj
# jasqn w'xjn nzybaj
# tzglv j'ktv vdxuzt
# rzmuo i'hro ovnszr
# wbygh f'mwh hvisbw
# dstxl p'wdl luahsd
# xijdw k'yxw wpcqix
# vycrb i'uvb bgolyv
# zitgy m'szy yenviz
# qfdnx o'mqx xazkfq
# kbsuz x'akz zmftbk
# szunr k'psr rqgdzs
# kywps l'tks sajxyk
# vjdqc r'nvc ctukjv
# fjthn k'wfn ndgujf
# iprtw o'uiw whabpi
# fwdma p'gfa aseiwf
# rjnls t'drs spamjr
# gempr w'jgr rlyceg
# xtwpz h'rxz zbjvtx
# indrc f'gic combni
# yihle x'tye ejgsiy
# jcnbs z'rjs syvmcj
# kleah y'wkh hdjulk
# wljfy i'rwy yxqolw
# mqojv g'umv vnysqm
# vnmks r'avs slxdnv
# uimxn c'run nygziu
# hxfjz c'shz ztunxh
# jfrin z'ajn ncdqfj
# kboyx s'mkx xnafbk
# qgtaj r'iqj jdvzgq
# qduob r'eqb bmswdq
# whlti v'uwi iqmxhw
# sodkc j'isc cwxhos
# miuxt k'pmt tzceim
# zwhko a'yzo ovxiwz
# wfsch a'pwh hzyxfw
# pgslx b'wpx xnrfgp
# ywtso z'ryo objlwy
# xkbnl g'zxl lpahkx
# rwdio n'xro otzvwr
# cneaf g'pcf fytxnc
# xjovt l'axt tqypjx
# atxuj q'gaj jrcbta
# mcdqj u'kmj jsfgcm
# vsjal c'evl ltphsv
# zthna j'mza abyptz
# vmczy b'tvy yldemv
# xwqga o'dxa aybjwx
# pitje x'hpe enzyip
# ubvgp m'zup pfnhbu
# xdkyq z'rxq qgaudx
# pfoue k'rpe egbmfp
# cvgnh j'zch harwvc
# fwmov n'gfv vhzrwf
# vnisx u'ovx xkfdnv
# imhoz x'diz zygkmi
# bgydu w'tbu umsvgb
# oxvdw i'pow wzkuxo
# uhwqt y'kut tdjlhu
# jlaqf w'ejf fzhclj
# gjhkl o'mgl layvjg
# thnrb x'gtb buqwht
# wosye p'bwe emvuow
# mekni u'smi ivoaem
# rgxsu i'qru uzvkgr
# eofjr m'uer rkgzoe
# xjaql t'ixl lfwyjx
# taqsd l'itd drxjat
# vnqzh p'ivh hjmanv
# wtonr a'cwr rpzmtw
# jepbo s'hjo owxlej
# jrebc g'ljc cqxurj
# sepra z'xsa agbkes
# yiplg e'myg gdfqiy
# frvlh t'kfh hoserf
# vkynp z'hvp pdwskv
# hckgw q'jhw wevich
# orgba m'hoa awtkro
# meyju c'zmu ubiwem
# hcosk j'lhk kvfrch
# fiahd p'lfd djtrif
# ekvnt b'yet trhoke
# ghuzk j'ngk kysdhg
# mubif h'ymf fsxeum
# bcafz v'lbz zgnwcb
# inhcv f'jiv vzwmni
# xpfyh e'ixh hcavpx
# bwvlo x'dbo oyfpwb
# zjpnl i'ozl lyqtjz
# cbrfz d'mcz zhvjbc
# vwlbe k'tve ehncwv
# sfumd c'jsd dwoxfs
# jrksw q'pjw wznxrj
# rvdnt s'ort tzfwvr
# wgaok f'uwk khrbgw
# nucwh e'dnh hpzmun
# gthnr c'kgr rluqtg
# bwfdy t'rby ymzuwb
# kzyul r'ekl lnvpzk
# gubso q'vgo ohwcug
# gojqi f'ygi iunlog
# coath q'zch hebkoc
# qiton b'wqn nsgaiq
# wfrjo i'hwo olabfw
# ohkeq d'foq qabwho
# qnwsz l'gqz zdvrnq
# jikqm z'ojm mhvcij
# dusxq f'wdq qonhud
# ygvcd i'zyd dubmgy
# mhzuv c'pmv vltdhm
# ogwnb k'fob bdspgo
# xkizu d'lxu ufeskx
# seivd b'fsd dmuoes
# gvcsf r'kgf fdjnvg
# zmacn y'xzn nlbjmz
# pkuxi w'opi iscjkp
# sylji e'xsi imagys
# teirp c'vtp pfmbet
# afkwv i'lav vmscfa
# ihwsl u'kil lnfghi
# wpfsj n'gwj jczqpw
# walzq s'iwq qktbaw
# xdaqn c'ixn nzltdx
# ylakt r'nyt tzocly
# dzeah x'kdh hswqzd
# qltkv e'cqv vzbglq
# csmqw y'jcw wknbsc
# kgmzd r'bkd dqhygk
# svbon w'csn nlifvs
# jmlby s'njy ykofmj
# aierf u'gaf fkhwia
# vwtzf m'bvf funewv
# isjvz h'tiz zxlesi
# ulnwx d'eux xsyplu
# giold h'zgd dmwcig
# ijhrt o'ait txnqji
# nuljk c'hnk kdowun
# ytgfr m'byr rvuwty
# deyof x'sdf fatzed
# dbpvw l'rdw woqsbd
# tbnjl x'qtl lwaibt
# lsmix z'alx xdjosl
# uvykm x'bum mwdfvu
# bjahu v'nbu uotgjb
# nwmlh f'bnh hxrswn
# ljswy e'nly yxhqjl
# hrudv q'ehv vmjprh
# beycn h'zbn nrvmeb
# rvtke z'cre eufjvr
# aimlq r'caq qgpeia
# sbxgd t'qsd deozbs
# emtir p'uer rnbome
# fspob e'kfb bcdmsf
# ljnup o'dlp payzjl
# ivslz e'piz zobmvi
# xrakh g'jxh hclsrx
# spmyw q'gsw wrcips
# tcjol r'wtl ldpect
# kfmct o'dkt tsbnfk
# rcmeh k'irh hofncr
# lvncx o'tlx xpywvl
# prtxh o'bph hzierp
# defvt l'kdt tquxed
# pcnvu g'hpu ujwzcp
# lpvkt n'qlt twcbpl
# kgwds m'hks siubgk
# acqlp j'iap pfwmca
# wjbgf s'iwf fedojw
# uwyvx l'iux xpbmwu
# wazqc p'hwc cigyaw
# ezafh o'geh hxudze
# nbqfg z'cng glktbn
# nrqye h'jne exwmrn
# ulgez n'juz zovdlu
# epsxn t'len nbyfpe
# unzgx r'wux xapjnu
# kwxrg b'ukg gdvfwk
# jgfqa l'tja acmwgj
# nyspw f'dnw wjkqyn
# sorbz v'msz zqcuos
# kmixr z'wkr ruhtmk
# leaxk y'ilk ksuoel
# pgnaf i'qpf fvmogp
# tpdvz i'rtz zcxmpt
# cpwan b'ecn ntdjpc
# upjml h'xul lsfepu
# gxrtk b'ygk kvcexg
# leaix o'dlx xwbuel
# bcgwj s'ybj jenmcb
# nfqvg x'cng grhifn
# bhvdm n'ebm mksrhb
# qvder c'uqr rnfovq
# zfloi s'hzi ixegfz
# bdeow x'vbw wfzgdb
# vgdlc f'ovc cazrgv
# xiams d'hxs sflzix
# tihza q'jta asbxit
# egybw r'zew wplvge
# cnfma y'ica auqznc
# agwhv u'fav vldoga
# tamow n'etw wgphat
# tzmcx g'stx xhklzt
# ychtj n'xyj jqvmcy
# ofmda e'yoa axzcfo
# mpukj y'nmj jwahpm
# gxuho l'mgo orbsxg
# ejpts v'ces soyaje
# bdypg t'abg gowfdb
# yvjxa q'hya agdevy
# dkwcp x'adp pvhykd
# cptxz h'ucz zrelpc
# angri u'jai izfhna
# noxhq e'dnq qjilon
# nepgu q'fnu ubaven
# vkngh w'ivh hobfkv
# argqx e'uax xhcpra
# bstmn l'gbn ncwesb
# ewxyl r'sel lhzpwe
# oativ l'cov vwqyao
# uxgpz b'quz zfnvxu
# sbydk n'lsk kvwqbs
# jqwra o'hja amduqj
# etnbw g'dew wjmpte
# baxcy m'kby ydlrab
# zkbhc g'jzc csuxkz
# rabds t'ers syofar
# wyfoc r'lwc cdbayw
# oupal e'kol lrmtuo
# gazbq n'fgq qheuag
# nrexd w'pnd dalqrn
# vmzyw d'jvw wrslmv
# vbsfd r'jvd dqzlbv
# qyntg w'eqg gfcvyq
# mwnyi x'omi iushwm
# owjgl k'dol ltafwo
# yrxvi p'lyi iueory
# nspvu o'inu uadesn
# rjswn e'hrn nubmjr
# pmyvi j'kpi iwghmp
# fubcq s'ofq qenduf
# zjmik s'yzk kxfujz
# nujys d'cns slqeun
# mgadt p'jmt tvszgm
# zarbs d'vzs slhqaz
# asqjt r'mat twicsa
# vqrmy f'kvy yudiqv
# jvbqu w'hju uyxlvj
# phbwg i'spg guyjhp
# olvbh e'koh hcwylo
# zuvot f'rzt tsdiuz
# laizo j'nlo omgval
# fzrvy a'wfy ycimzf
# iojcs d'nis stvaoi
# fredh i'vfh hqnmrf
# phqly d'zpy ywnkhp
# vytal e'kvl lhjryv
# vdxop z'wvp pryfdv
# yegnb l'fyb bijuey
# xokjb t'yxb bnwuox
# yxnle g'vye eufsxy
# uqkmh r'vuh hoedqu
# yulfg x'iyg gzkwuy
# tgmvd b'ctd dehkgt
# pxvsh w'cph hoyjxp
# jgyte h'sje eqongj
# ercvj f'tej jqsore
# ohukw i'row wgsbho
# zhodp r'szp pclbhz
# jusne x'mje ewfguj
# kobxw n'jkw wyuzok
# fvsxo m'nfo ogwrvf
# vqnzk l'uvk kcxpqv
# vzknw e'xvw wtdozv
# pzcgt q'vpt taiuzp
# tbenr j'otr rdmkbt
# gqsat h'vgt txdwqg
# eaopj t'mej jrxuae
# yvfnq d'syq qoazvy
# bfywn t'cbn nhrxfb
# ltarm i'xlm mwbntl
# mkqgz p'emz zlwdkm
# bgptl a'rbl lecfgb
# oabgz y'xoz zukjao
# kptiv j'okv vghepk
# fhktw b'yfw wcishf
# zocfe s'wze embqoz
# brwyv d'zbv vfporb
# fpyua g'vfa axdrpf
# mwhiu d'kmu uolswm
# hiukp f'qhp pyxtih
# vmfnp u'xvp pcrdmv
# gfipc y'jgc cwatfg
# leiup o'jlp pymzel
# cktlf s'icf fozwkc
# lzktp u'rlp pvjmzl
# dlqmo k'hdo obaxld
# fpaxs e'bfs smrhpf
# wypkz c'jwz ztfxyw
# qykap w'xqp pmityq
# cvows j'pcs srglvc
# xyqro g'dxo oeukyx
# okuzl w'iol lrcbko
# cxglj o'tcj jbzwxc
# wzgev k'nwv vycmzw
# rvxaq j'krq qhuivr
# cfbdv s'zcv vaykfc
# ujmqv i'luv vrhnju
# gthur o'pgr rljktg
# apwuq o'eaq qdmypa
# mbled q'ymd dvtrbm
# fwjlo x'dfo oykuwf
# irbkx n'wix xqemri
# kufjn h'pkn ntwquk
# dprst n'kdt tcbmpd
# jzswt n'cjt tuexzj
# gibjo m'ago osqcig
# kwrpb z'akb buinwk
# jubmc x'sjc conquj
# mxjis z'wms srlgxm
# eofna s'wea agcvoe
# dogte u'qde eawhod
# rwubi m'fri ieskwr
# sekit v'ast tmxjes
# ufcbx z'oux xpqgfu
# ulaqx j'nux xzoflu
# sofpc v'nsc cjwgos
# kqcml i'hkl lvbaqk
# ousia v'yoa ahbluo
# qwtac i'xqc cpjrwq
# ozagk u'mok kclpzo
# dtbku n'idu uyestd
# fbrmu n'qfu upzabf
# troaf z'qtf fxulrt
# jveth g'rjh hwbyvj
# zuprb o'czb bxjluz
# hbtrf d'vhf fmzwbh
# qawzh d'uqh hgsfaq
# aewrm t'iam mnofea
# aricw o'paw wqvxra
# blsma c'dba auitlb
# zjyrg s'izg gtukjz
# qsmvt c'yqt tzepsq
# qewsf x'zqf fpckeq
# mstwl q'jml lvyhsm
# zgeal m'czl lvrkgz
# nbsyp f'qnp plrebn
# hugqj m'khj jdiyuh
# hxrnj g'ahj jsvpxh
# cmdvh w'pch haubmc
# eiflr h'yer ratjie
# izlsh u'gih hcxazi
# bzhvy m'pby ygfizb
# keuol m'vkl lrthek
# wjxnk q'swk kuzljw
# oijzd h'wod dvksio
# cnapq k'jcq qbvlnc
# vgkua t'sva ameqgv
# cngid y'kcd dfaenc
# dgafw h'sdw wbqcgd
# jdmeu r'zju ufgbdj
# byeoa c'qba akvgyb
# kbygz w'tkz zvpobk
# qifge m'rqe eytwiq
# fwzej s'cfj jbqnwf
# hfjlt o'iht tegyfh
# prqsv t'upv vbafrp
# plovh t'sph hjiklp
# dxjsw c'udw wfyaxd
# oqmea g'coa akwfqo
# lvdya r'tla apsevl
# bwlmq h'kbq qpxiwb
# lprtx a'jlx xfegpl
# ksfbi g'yki imdhsk
# yqxhb e'lyb bvorqy
# ufzlb m'qub bxwvfu
# cumfq p'lcq qajguc
# ckfvr o'scr rgxjkc
# yxlri k'vyi inpcxy
# xzdiw p'axw wourzx
# ftndi w'xfi iubztf
# omtcl k'iol lvjumo
# frwep m'hfp pxlorf
# ivdyl s'ail luocvi
# lrmgn u'zln nsowrl
# axloy b'day ynkwxa
# bnkej r'wbj jhycnb
# euwyr f'xer rmague
# synit a'vst tefqys
# jgphy v'rjy ymoegj
# lqjxy r'uly yhdiql
# lpuyt z'clt tmnqpl
# ijklx c'yix xrumji
# czhsr t'qcr rlinzc
# gxmen y'fgn ndlaxg
# atrzx g'lax xkhsta
# cythv q'fcv vzadyc
# eaong w'xeg gjdkae
# dxfcs b'nds sgapxd
# pizjg q'cpg gstaip
# qjriv s'wqv vgpujq
# nszoh t'jnh hvdusn
# {"xnsip m'bxp pquznx ": 1, "rcnod u'ird dthzcr ": 1, "gctuj k'pgj jiexcg ": 1, "echdw j'sew wpioce ": 1, "wxvsj h'kwj jfcpxw ": 1, "knxlt g'ikt tosdnk ": 1, "guarp w'hgp ploeug ": 1, "jzcok i'fjk kewbzj ": 1, "dwvcj q'bdj jsfawd ": 1, "saflc u'hsc cqotas ": 1, "bojxv r'fbv vhdgob ": 1, "novhg y'rng glceon ": 1, "naguo j'sno olvran ": 1, "mqweh r'fmh hbskqm ": 1, "zprfg h'bzg gclqpz ": 1, "estju x'weu uqmhse ": 1, "qckrg o'wqg gulmcq ": 1, "vhzml q'jvl ltewhv ": 1, "hvkxf s'bhf filyvh ": 1, "qfbhy a'cqy ynrufq ": 1, "sxczl r'ysl lqiwxs ": 1, "mupbt y'gmt taqxum ": 1, "cupht k'fct tmvauc ": 1, "woeqy a'nwy yihdow ": 1, "eacsf o'lef fqbxae ": 1, "aqjne c'rae eomzqa ": 1, "ilnqw t'jiw wxvpli ": 1, "xwlyu g'sxu utonwx ": 1, "rofwn q'lrn nmuzor ": 1, "ogpjc h'koc cwylgo ": 1, "yhtne x'sye ecrjhy ": 1, "fvatr j'xfr rbsivf ": 1, "stazu j'isu uqfnts ": 1, "zhmwi l'vzi iqaghz ": 1, "thigy u'mty ypbkht ": 1, "htwuj g'ehj jvcnth ": 1, "bvalc o'dbc ckxgvb ": 1, "ivanj d'yij jmwsvi ": 1, "iwmrd u'eid dlkawi ": 1, "cxwpy z'qcy ybgkxc ": 1, "ionqs p'jis sdgboi ": 1, "fxqny p'dfy ybagxf ": 1, "gknme r'zge ejclkg ": 1, "ulyiq d'huq qrjvlu ": 1, "gweay j'qgy yvzuwg ": 1, "vuzao e'qvo okipuv ": 1, "wskdz c'mwz zevisw ": 1, "saqpx m'isx xucfas ": 1, "patsd r'lpd dcubap ": 1, "lroqy z'sly yxcarl ": 1, "esjzq d'veq qybmse ": 1, "zteox j'szx xfmqtz ": 1, "nyprq l'znq qtxbyn ": 1, "pyqhl c'apl lokfyp ": 1, "ioxjw l'eiw wkhvoi ": 1, "wvshq o'dwq qaebvw ": 1, "wmuns y'ows stgamw ": 1, "whmcf e'kwf fzsjhw ": 1, "urmkj b'iuj jztwru ": 1, "cxnhu d'jcu uomrxc ": 1, "cilon g'vcn ntkyic ": 1, "hjqov g'thv viukjh ": 1, "wgqpi v'hwi icaugw ": 1, "biekl s'obl lmzvib ": 1, "jnmag p'cjg gekwnj ": 1, "oixaz f'moz zevwio ": 1, "cukby m'xcy yazguc ": 1, "vstiy d'wvy yrflsv ": 1, "uyfad e'nud dktiyu ": 1, "wxdri z'lwi itvpxw ": 1, "fzpxw k'qfw woerzf ": 1, "cftvi h'gci iqjxfc ": 1, "gnqkw e'hgw waxing ": 1, "tmugh d'vth hpnsmt ": 1, "wbtrh a'uwh hlfxbw ": 1, "gcpbe u'nge evmscg ": 1, "pnxjw a'bpw wglcnp ": 1, "giotd p'kgd dvrqig ": 1, "uptaj b'ruj jdcxpu ": 1, "eagtn b'cen ndirae ": 1, "dngau e'vdu ubjfnd ": 1, "uctoh e'ruh hvkqcu ": 1, "ohrvs a'bos sxpnho ": 1, "qflov g'xqv vunzfq ": 1, "psynv j'epv vgfzsp ": 1, "pawrh d'bph hoizap ": 1, "hrevm k'whm maybrh ": 1, "pmwsl i'bpl lhogmp ": 1, "nwdcv y'hnv vkeown ": 1, "sabpx z'tsx xqmeas ": 1, "phiwc k'lpc cqzdhp ": 1, "tsuhf b'itf fdmwst ": 1, "hlbmt y'ght tszilh ": 1, "zgpty u'nzy yavmgz ": 1, "avjmt w'uat tfsqva ": 1, "nyecz t'qnz zmixyn ": 1, "bpexa q'fba atznpb ": 1, "tpmld y'ctd degvpt ": 1, "gqpze s'mge elbcqg ": 1, "zbcir x'qzr rlgabz ": 1, "uecxt y'mut tdgpeu ": 1, "ajbyw f'saw wrikja ": 1, "jorpv t'ejv vicwoj ": 1, "dtzku j'cdu ugbotd ": 1, "xrnjp f'mxp pgwhrx ": 1, "tmchx z'ktx xgsemt ": 1, "hcpzy m'thy yjruch ": 1, "pernv t'xpv vasqep ": 1, "adlrg o'sag gpfjda ": 1, "zmfdt o'gzt tclnmz ": 1, "ygmkw t'lyw wjdcgy ": 1, "pfagt y'kpt tzcofp ": 1, "lawyf j'elf fgnual ": 1, "onmjv w'tov vkblno ": 1, "stzox b'dsx xwfjts ": 1, "payds g'vps szjrap ": 1, "ogwje s'yoe efqrgo ": 1, "jvfom z'xjm mlhcvj ": 1, "gehwq a'ngq qbdieg ": 1, "uirfj g'euj jzaqiu ": 1, "ecvrg i'keg gwftce ": 1, "ajprq d'faq qmsxja ": 1, "ufaqc k'ruc cnbdfu ": 1, "wzqsi v'mwi ihynzw ": 1, "fugzt h'cft tpleuf ": 1, "jnumt y'zjt tcvlnj ": 1, "dnwui p'xdi ijoand ": 1, "iyqjg h'kig gvroyi ": 1, "qcrgj m'dqj jhuscq ": 1, "nxflp z'gnp phcmxn ": 1, "lzqfk m'vlk kwajzl ": 1, "qrabj g'kqj jidyrq ": 1, "txzqr s'btr rjlkxt ": 1, "snbcf d'hsf fywans ": 1, "ciybh l'jch hzdvic ": 1, "fgpnh u'ifh hvotgf ": 1, "eilrt v'jet tnxwie ": 1, "shval q'rsl lceyhs ": 1, "pmuni b'cpi ilexmp ": 1, "pxsdw z'npw wevhxp ": 1, "vryed l'wvd dzxqrv ": 1, "dgcko y'rdo oazlgd ": 1, "coebj x'acj jgukoc ": 1, "zuves n'bzs soaruz ": 1, "jcwsr o'mjr rnykcj ": 1, "soqlr w'ksr rizgos ": 1, "uiczp s'nup pjxdiu ": 1, "elxto m'ceo oksple ": 1, "nketq r'unq qyjmkn ": 1, "ptxyh z'fph hqwetp ": 1, "vumei s'gvi ifjruv ": 1, "brvmp q'ebp pkyarb ": 1, "spxbj g'ksj jtuips ": 1, "htrna d'kha aofpth " ...
